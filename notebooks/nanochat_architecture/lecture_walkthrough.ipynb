# %% [markdown]
# # Nanochat Architecture

# %%
from pathlib import Path
from pprint import pprint

LECTURE_NOTE_PATH = Path('/Users/montekkundan/Library/Mobile Documents/iCloud~md~obsidian/Documents/lectures/LLM/product/Nanochat Architecture.md')
print(LECTURE_NOTE_PATH)
# Out:
# /Users/montekkundan/Library/Mobile Documents/iCloud~md~obsidian/Documents/lectures/LLM/product/Nanochat Architecture.md

# %% [markdown]
# ## Demo A: the course repo architecture map

# %%
architecture = {
    'concept notebooks': 'notebooks/<topic>/lecture_walkthrough.ipynb',
    'shared runtime': 'course_tools/runtime.py',
    'training': 'scripts/base_training_flow/run.py',
    'evaluation': 'scripts/base_evaluation_flow/run.py',
    'chat workflow': 'notebooks/real_chatbot_workflow/lecture_walkthrough.ipynb',
    'inference': 'notebooks/inference_runtime_and_kv_cache/lecture_walkthrough.ipynb',
    'product stack': 'picollm/'
}
architecture
# Out:
# {'concept notebooks': 'notebooks/<topic>/lecture_walkthrough.ipynb',
#  'shared runtime': 'course_tools/runtime.py',
#  'training': 'scripts/base_training_flow/run.py',
#  'evaluation': 'scripts/base_evaluation_flow/run.py',
#  'chat workflow': 'notebooks/real_chatbot_workflow/lecture_walkthrough.ipynb',
#  'inference': 'notebooks/inference_runtime_and_kv_cache/lecture_walkthrough.ipynb',
#  'product stack': 'picollm/'}

# %% [markdown]
# ## Demo B: compare the simplified course split with nanochat-style product layers

# %%
nanochat_layers = [
    'tokenizer.py',
    'gpt.py',
    'dataloader.py',
    'engine.py',
    'scripts/base_train.py',
    'scripts/chat_sft.py',
    'scripts/chat_web.py',
]
for item in nanochat_layers:
    print(item)
# Out:
# tokenizer.py
# gpt.py
# dataloader.py
# engine.py
# scripts/base_train.py
# scripts/chat_sft.py
# scripts/chat_web.py
